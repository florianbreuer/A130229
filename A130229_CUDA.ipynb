# %% [markdown]
# Sequence <a href="https://oeis.org/A130229">A130229</a> in the OEIS consists of primes $p \equiv 5 \bmod 8$ for which the Pellian equation
# $$
# x^2 - p y^2 = -4
# $$
# no solutions in odd integers. Equivalently, let $K = \mathbb{Q}(\sqrt{p})$ with ring of integers $\mathcal{O}_K = \mathbb{Z}[\frac{1+\sqrt{p}}{2}]$ and fundamental unit $\varepsilon_p = \frac{x_0 + y_0\sqrt{p}}{2}$. Here $(x_0, y_0)$ is a fundamental solution to the Pellian equation above and $p$ is an element of A130229 if and only if $x_0$ and $y_0$ are even, equivalently $\varepsilon_p \equiv 1 \bmod 2\mathcal{O}_K$.
#
# Note that $2$ is inert in $K/\mathbb{Q}$, so there are three possible non-zero residue classes for $\varepsilon_p \bmod 2\mathcal{O}_K$. Heuristically, one thus expects about one third of all primes $p \equiv 5 \bmod 8$ to be members of this sequence.
#
# The present notebook contains code to test this heuristic. We define two counting functions for the sequence A130229. The naive counting function is
# $$\pi_1(x) = \sum_{p\in A130229, \; p\leq x} 1.$$
# For a better counting function, first define
# $$\chi(p) = \left\{ \begin{array}{ll}
# 1 & \text{if $p \equiv 5 \bmod 8$ and $\varepsilon_p \equiv 1 \bmod 2\mathcal{O}_K$} \\
# -\frac{1}{2} & \text{if $p \equiv 5 \bmod 8$ and $\varepsilon_p \not\equiv 1 \bmod 2\mathcal{O}_K$} \\
# 0 & \text{if $p \not\equiv 5 \bmod 8$.}
# \end{array}
# \right.
# $$
# Now set
# $$
# \theta_\chi(x) := \sum_{p \leq x} \chi(p)\log p.
# $$
# Our heuristc leads us to expect that $\theta_\chi(x) = o(x)$, i.e. that the terms mostly cancel out.
#
# The code below computes the fundamental solution $(x_0, y_0) \bmod 2$ using the continued fraction method, with $B_i$ and $G_i$ reduced mod 2 at each step. The code computes this in parallel for many primes $p$ on a GPU.

# %%
from sympy import isprime
from datetime import datetime
import math
import numpy as np
from time import localtime, strftime   
from numba.cuda.random import create_xoroshiro128p_states, xoroshiro128p_uniform_float32
from numba import cuda


# first, build a sieving list of primes below 2**20:
small_primes = []

# Yes, it's inefficient, but we only run this once, so that makes no difference
for p in range(3, 2**20):
    if isprime(p):
        small_primes.append(p)

small_primes_arr = np.array(small_primes, dtype=np.uint32)


def size_str(n):
    '''Return str describing size of n bytes in kB, MB, GB,...'''
    if n < 1024:
        return f'{n} bytes'
    elif n < 1048576:
        return f'{(n/1024):.04} kB'
    elif n < 1073741824:
        return f'{(n/1048576):.04} MB'
    elif n < 1099511627776:
        return f'{(n/1073741824):.04} GB'
    else:
        return f'{(n/1099511627776):.04} TB'


# This is the Python function you want to run on the GPU
@cuda.jit
def Pell_Lambda_sieved_kernel(input_array, output_array): #, error_flag):
    '''
    This is supposed to run on a GPU.
    input_array contains prime numbers congruent to 5 mod 8.
    output_array will store the outputs of the form log(p) or -0.5*log(p), depending on the parity of the fundamental unit.
    '''
    idx = cuda.grid(1)
    if idx < input_array.size:  # Check array bounds
        p = input_array[idx]
        sqrt_p = np.uint64(math.sqrt(np.float64(p))) 
        P = np.uint64(1)
        Q = np.uint64(2)
        q = np.uint64((1 + sqrt_p) / 2)
        B = np.uint8(1)
        B_old = np.uint8(0)
        G = np.uint8(((2*q) - 1) % 2)
        G_old = np.uint8(0)
    
        # First iteration
        P = (q*Q) - P
        Q = (p - (P*P)) / Q
        q = np.uint64((P + sqrt_p) / Q)
        # G_old, G = G, ((q*G + G_old) % 2)
        # B_old, B = B, ((q*B + B_old) % 2)
        G_old, G = G, (q & G & 1) ^ G_old
        B_old, B = B, (q & B & 1) ^ B_old
    
        # main loop:
        while Q != 2:
            P = (q*Q) - P
            Q = (p - (P*P)) / Q
            q = np.uint64((P + sqrt_p) / Q)
            G_old, G = G, (q & G & 1) ^ G_old
            B_old, B = B, (q & B & 1) ^ B_old
            # G_old, G = G, ((q*G + G_old) % 2)
            # B_old, B = B, ((q*B + B_old) % 2)

            # # how big do P and Q get?
            # if P > error_flag[0]:
            #     error_flag[0] = P
            # if Q > error_flag[1]:
            #     error_flag[1] = Q

            # # check for potential overflow errors:
            # if P > 2147483648 or Q > 2147483648:
            #     error_flag[0] = 1

        if G_old == 0:
            output_array[idx] = math.log(np.float64(p))
        else:
            output_array[idx] = -0.5*math.log(np.float64(p))




def primes_5mod_8(a, b):
    '''Return array containing all primes 5 mod 8 in interval [a, b)'''
    if a < 5:
        N_1 = 0
    else:
        N_1 = np.int64(np.ceil((a - 5) / 8))
    if b < 5:
        N_2 = 0
    else:
        N_2 = np.int64(np.floor((b - 5) / 8))
        if 8*N_2 + 5 < b:
            N_2 += 1
    chunk_size = np.int64(N_2 - N_1)
    # print(N_1, N_2)
    # print(8*N_1+5, 8*N_2+5)
    if chunk_size <= 0:
        return np.array(0, dtype=np.uint64)
      
    sieve = np.ones(chunk_size, dtype=bool)  # initialise sieve
    
    for p in small_primes_arr:
        if np.int64(p)**2 >= b:  # only check primes < sqrt(N_8) - avoid overflow in squaring!
            break
        # get starting index k for 8(N + k) + 5 is a multiple of p
        d = (p & 7) ^ 4  # so that d*p = 5 mod 8
        k_start = np.int64(((d*p-5)//8 - N_1) % p)
        if 8*(k_start + N_1) + 5 == p:  # don't kill p itself
            k_start += p
        # now sieve:
        sieve[k_start :: p] = False

    return 8*(N_1 + np.nonzero(sieve)[0])+5


def theta_pi_kernel(a, b, verbose=True):
    '''Return theta(b) - theta(a)'''
    # first, create an array of prime numbers 5 mod 8 in the interval (a, b]
    if verbose:
        print(f'   Sieving primes in interval [{a+1}, {b+1})...')
    input_array = primes_5mod_8(a+1, b+1)
    if input_array.shape == () or input_array.size == 0:
        return 0.0, 0
    if verbose:
        print(f'    {input_array.size} primes found. Sending block [{input_array[0]}, ... ,{input_array[-1]}] of size {size_str(input_array.nbytes)} to GPU.')
    output_array = np.zeros_like(input_array, dtype=np.float64)  # for results
    d_input_array = cuda.to_device(input_array)
    d_output_array = cuda.to_device(output_array)

    # Run the kernel on the GPU
    threads_per_block = 256 # seems a good choice for my entry-level gaming laptop...
    blocks = (input_array.size + (threads_per_block - 1)) // threads_per_block
    Pell_Lambda_sieved_kernel[blocks, threads_per_block](d_input_array, d_output_array) #, d_error_flag)

    # Copy the results back to the host
    output_array = d_output_array.copy_to_host()
    theta_result = np.sum(output_array)
    pi_result = np.count_nonzero(output_array > 0)   # I hope this is right, we want to count the number of primes for which positive result is returned
    if verbose:
        print(f'     Result: theta =  {theta_result};  pi = {pi_result}')
    return theta_result, pi_result
    
    
    
def complete_theta(X, verbose=True):
    '''Return list of points (x, theta(x)) for x <= X.'''
    # first, create an array of prime numbers 5 mod 8 in the interval [a, b]
    if verbose:
        print(f'Sieving primes in interval [2, {X}]...')
    input_array = primes_5mod_8(2, X+1)
    if verbose:
        print(f' {input_array.size} primes found. Sending block of size {size_str(input_array.nbytes)} to GPU.')
    output_array = np.zeros_like(input_array, dtype=np.float64)  # for results
    d_input_array = cuda.to_device(input_array)
    d_output_array = cuda.to_device(output_array)

    # Run the kernel on the GPU
    threads_per_block = 256 #256
    blocks = (input_array.size + (threads_per_block - 1)) // threads_per_block
    Pell_Lambda_sieved_kernel[blocks, threads_per_block](d_input_array, d_output_array) #, d_error_flag)

    # Copy the results back to the host
    output_array = d_output_array.copy_to_host()
    if verbose:
        print(np.sum(output_array))

    # now read through the results and add up theta as we go
    result = []
    theta = 0.0
    i = 0
    for x in range(X+1):
        p = input_array[i]
        if x == p:
            theta += output_array[i]
            if i < input_array.size - 1:
                i += 1
        result.append((x, theta))
    return result


def A130229(X, verbose=True):
    '''
    Returns a list of members of sequence A130229 less than X.
    '''
    # first, create an array of prime numbers 5 mod 8 in the interval [a, b]
    if verbose:
        print(f'Sieving primes in interval [2, {X}]...')
    input_array = primes_5mod_8(2, X+1)
    if verbose:
        print(f' {input_array.size} primes found. Sending block of size {size_str(input_array.nbytes)} to GPU.')
    output_array = np.zeros_like(input_array, dtype=np.float64)  # for results
    d_input_array = cuda.to_device(input_array)
    d_output_array = cuda.to_device(output_array)

    # Run the kernel on the GPU
    threads_per_block = 256 #256
    blocks = (input_array.size + (threads_per_block - 1)) // threads_per_block
    Pell_Lambda_sieved_kernel[blocks, threads_per_block](d_input_array, d_output_array) #, d_error_flag)

    # Copy the results back to the host
    output_array = d_output_array.copy_to_host()
    if verbose:
        print(np.sum(output_array))

    # now return the results, i.e. primes p for which lambda(p) > 0
    result = []
    for p, l in zip(input_array, output_array):
        if l > 0:
            result.append(p)

    return result

# %%
# lets compute all members of sequence A130229 below 10^8 and write them to a file

sequence_filename = 'A130229.txt'
X = 10**8

with open(sequence_filename, 'w') as sequence_file:
    for p in A130229(X):
        sequence_file.write(str(p)+',\n')
# Out:
# Sieving primes in interval [2, 100000000]...
#  1440534 primes found. Sending block of size 10.99 MB to GPU.
# -306598.8227363084

# %% [markdown]
# What we really want is $\theta_\chi(x)$ for $x \leq 10^{11}$. That's too many points to store them all, so we'll compute a list of the form $(x, \theta_\chi(x))$, where $x$ runs through multiples of $10^n$ for suitable $n$.

# %%
# these are the main functions to call:

# don't make this too big - otherwise the GPU will be busy for 2h and we can't interrupt it...
MAX_INPUT_RANGE = 100000000   # widest range of inputs we'll send to GPU in one go

log_file_name = 'Pell_computations.log'

import logging
from datetime import datetime

# Configure the logging system
logging.basicConfig(
    filename=log_file_name,  # Log to this file
    level=logging.INFO,     # Set the logging level
    format='%(asctime)s - %(levelname)s - %(message)s'  # Include timestamp
)

def theta_GPU_linear(x_start=0, dx=1, N_points=1000, save_file=None, pi_file=None, resume=False,  more_points=0, verbose=True):
    '''Compute Pell_theta function on a list of N_points spaced linearly dx apart and starting with X_start.'''
    logging.info(f'Launching theta_GPU_linear: x_start = {x_start}, dx = {dx}, N_points = {N_points}, save_file: {save_file}, pi_file: {pi_file}, resume: {resume}, more_points: {more_points}')
    if not resume:   # create new files, write headers
        if save_file is not None:
            with open(save_file, "a") as f:
                f.write('\n'+strftime('%c')+'\n'+'x_start = '+str(x_start)+', dx = '+str(dx)+'\n'+'N_points = '+str(N_points)+'\n')
        if pi_file is not None:
            with open(pi_file, "a") as f:
                f.write('\n'+strftime('%c')+'\n'+'x_start = '+str(x_start)+', dx = '+str(dx)+'\n'+'N_points = '+str(N_points)+'\n')
    if resume:
        # read last point in psi_file:
        with open(save_file, 'r') as f:
            psi_contents = f.read()
        ll = psi_contents.split('\n')[-2]
        pt = eval(ll.strip())
        x_start = pt[0] + dx
        # last_i = int(math.log(pt[0])*N_points/math.log(X))
        x_list = [x_start + i*dx for i in range(N_points)] 
        theta = pt[1]
        a = int(pt[0])
        L = []
        if verbose:
            print(f'Resuming psi computations from {save_file}; last point {pt}.')
        # now do the same for the pi_file:
        if pi_file is not None:
            with open(pi_file, 'r') as f:
                pi_contents = f.read()
            llp = pi_contents.split('\n')[-2]
            pt = eval(llp.strip())
            pi_val = pt[1]
            L_pi = []
            if verbose:
                print(f'Resuming *pi* computations from {save_file}; last point {pt}.')
    else: 
        x_list = [x_start + i*dx for i in range(N_points)]   # list of x-values at which to evaluate psi(x)
        theta = 0.0
        pi_val = 0
        a = 0 
        L = []
        L_pi = []
    for i, x in enumerate(x_list):
        b = int(x)
        # now the range in which to compute is (a+1, b+1)
        # If b-a is too big, split it up further
        ranges = [(i, min(i + MAX_INPUT_RANGE, b)) for i in range(a, b, MAX_INPUT_RANGE)]
        if verbose:
            print(f'x = {x}')
            if len(ranges) > 1:
                print(f" Splitting into {len(ranges)} blocks.")
            
        for j, (aa, bb) in enumerate(ranges):
            if verbose:
                print(f" - Block {j+1} of {len(ranges)}: {(aa, bb)}")
            if bb > aa:
                logging.info(f' - Sending block {j+1} of {len(ranges)}: ({aa}, {bb}) to GPU.')
                result = theta_pi_kernel(aa, bb, verbose=verbose)
                # (new_theta, new_pi) = theta_pi_kernel(aa, bb, verbose=verbose)
                theta += result[0]
                pi_val += result[1]
                logging.info(f' - - Result: {result}')
                # theta += random_theta_kernel(aa, bb, verbose=verbose)
                # theta += test_theta_kernel(aa, bb, verbose=verbose)

        a = int(x)
        L.append((x, theta))
        L_pi.append((x, pi_val))
        logging.info(f' - - - Appending point x = {x}, theta(x) = {theta}, pi(x) = {pi_val}')
        if verbose:
            print(f"{datetime.now()}: Point {i+1} of {len(x_list)}, x = {x}, theta(x) = {theta}, pi(x) = {pi_val}")
        if save_file:
            with open(save_file,"a") as f:
                f.write(str((x, theta))+'\n')
        if pi_file:
            with open(pi_file,"a") as f:
                f.write(str((x, pi_val))+'\n')
        # elif resume_file:
        #     with open(resume_file,"a") as f:
        #         f.write(str((x,theta))+'\n')
    return L, L_pi

# %%
# small example:
theta_list, pi_list = theta_GPU_linear(x_start=0, dx=100000, N_points=100, save_file='Pell-theta-test.txt', pi_file='Pell-pi-test.txt')
# Out:
# x = 0
# 2024-08-11 02:52:43.103500: Point 1 of 100, x = 0, theta(x) = 0.0, pi(x) = 0
# x = 100000
#  - Block 1 of 1: (0, 100000)
#    Sieving primes in interval [1, 100001)...
#     2399 primes found. Sending block [5, ... ,99989] of size 18.74 kB to GPU.
#      Result: theta =  -887.5653633006716;  pi = 741
# 2024-08-11 02:52:43.109468: Point 2 of 100, x = 100000, theta(x) = -887.5653633006716, pi(x) = 741
# x = 200000
#  - Block 1 of 1: (100000, 200000)
#    Sieving primes in interval [100001, 200001)...
#     2112 primes found. Sending block [100069, ... ,199933] of size 16.5 kB to GPU.
#      Result: theta =  -234.76439762608555;  pi = 691
# 2024-08-11 02:52:43.140850: Point 3 of 100, x = 200000, theta(x) = -1122.3297609267572, pi(x) = 1432
# x = 300000
#  - Block 1 of 1: (200000, 300000)
#    Sieving primes in interval [200001, 300001)...
#     2012 primes found. Sending block [200029, ... ,299941] of size 15.72 kB to GPU.
#      Result: theta =  -1017.8586108385086;  pi = 616
# 2024-08-11 02:52:43.151873: Point 4 of 100, x = 300000, theta(x) = -2140.188371765266, pi(x) = 2048
# x = 400000
#  - Block 1 of 1: (300000, 400000)
#    Sieving primes in interval [300001, 400001)...
#     1973 primes found. Sending block [300109, ... ,399989] of size 15.41 kB to GPU.
#      Result: theta =  -527.6386638189574;  pi = 630
# 2024-08-11 02:52:43.176014: Point 5 of 100, x = 400000, theta(x) = -2667.8270355842233, pi(x) = 2678
# x = 500000
#  - Block 1 of 1: (400000, 500000)
#    Sieving primes in interval [400001, 500001)...
#     1901 primes found. Sending block [400069, ... ,499973] of size 14.85 kB to GPU.
#      Result: theta =  -814.3386240041893;  pi = 592
# 2024-08-11 02:52:43.186937: Point 6 of 100, x = 500000, theta(x) = -3482.1656595884124, pi(x) = 3270
# x = 600000
#  - Block 1 of 1: (500000, 600000)
#    Sieving primes in interval [500001, 600001)...
#     1905 primes found. Sending block [500029, ... ,599941] of size 14.88 kB to GPU.
#      Result: theta =  -1130.2974910605876;  pi = 578
# 2024-08-11 02:52:43.197935: Point 7 of 100, x = 600000, theta(x) = -4612.463150649, pi(x) = 3848
# x = 700000
#  - Block 1 of 1: (600000, 700000)
#    Sieving primes in interval [600001, 700001)...
#     1862 primes found. Sending block [600053, ... ,699757] of size 14.55 kB to GPU.
#      Result: theta =  -132.10210330783286;  pi = 614
# 2024-08-11 02:52:43.209733: Point 8 of 100, x = 700000, theta(x) = -4744.565253956834, pi(x) = 4462
# x = 800000
#  - Block 1 of 1: (700000, 800000)
#    Sieving primes in interval [700001, 800001)...
#     1809 primes found. Sending block [700109, ... ,799949] of size 14.13 kB to GPU.
#      Result: theta =  -891.4983518422703;  pi = 559
# 2024-08-11 02:52:43.223526: Point 9 of 100, x = 800000, theta(x) = -5636.063605799104, pi(x) = 5021
# x = 900000
#  - Block 1 of 1: (800000, 900000)
#    Sieving primes in interval [800001, 900001)...
#     1841 primes found. Sending block [800029, ... ,899981] of size 14.38 kB to GPU.
#      Result: theta =  -750.108858405838;  pi = 577
# 2024-08-11 02:52:43.236770: Point 10 of 100, x = 900000, theta(x) = -6386.172464204942, pi(x) = 5598
# x = 1000000
#  - Block 1 of 1: (900000, 1000000)
#    Sieving primes in interval [900001, 1000001)...
#     1809 primes found. Sending block [900037, ... ,999917] of size 14.13 kB to GPU.
#      Result: theta =  -21.362682451031468;  pi = 602
# 2024-08-11 02:52:43.248896: Point 11 of 100, x = 1000000, theta(x) = -6407.535146655973, pi(x) = 6200
# x = 1100000
#  - Block 1 of 1: (1000000, 1100000)
#    Sieving primes in interval [1000001, 1100001)...
#     1817 primes found. Sending block [1000037, ... ,1099997] of size 14.2 kB to GPU.
#      Result: theta =  -240.49552351574857;  pi = 594
# 2024-08-11 02:52:43.259405: Point 12 of 100, x = 1100000, theta(x) = -6648.030670171722, pi(x) = 6794
# x = 1200000
#  - Block 1 of 1: (1100000, 1200000)
#    Sieving primes in interval [1100001, 1200001)...
#     1825 primes found. Sending block [1100093, ... ,1199909] of size 14.26 kB to GPU.
#      Result: theta =  -111.29123550897536;  pi = 603
# 2024-08-11 02:52:43.270870: Point 13 of 100, x = 1200000, theta(x) = -6759.3219056806975, pi(x) = 7397
# x = 1300000
#  - Block 1 of 1: (1200000, 1300000)
#    Sieving primes in interval [1200001, 1300001)...
#     1768 primes found. Sending block [1200061, ... ,1299989] of size 13.81 kB to GPU.
#      Result: theta =  -826.9007411058456;  pi = 550
# 2024-08-11 02:52:43.283124: Point 14 of 100, x = 1300000, theta(x) = -7586.222646786543, pi(x) = 7947
# x = 1400000
#  - Block 1 of 1: (1300000, 1400000)
#    Sieving primes in interval [1300001, 1400001)...
#     1793 primes found. Sending block [1300021, ... ,1399861] of size 14.01 kB to GPU.
#      Result: theta =  -967.0750887708671;  pi = 552
# 2024-08-11 02:52:43.295867: Point 15 of 100, x = 1400000, theta(x) = -8553.29773555741, pi(x) = 8499
# x = 1500000
#  - Block 1 of 1: (1400000, 1500000)
#    Sieving primes in interval [1400001, 1500001)...
#     1737 primes found. Sending block [1400029, ... ,1499933] of size 13.57 kB to GPU.
#      Result: theta =  127.75470100309175;  pi = 585
# 2024-08-11 02:52:43.308617: Point 16 of 100, x = 1500000, theta(x) = -8425.543034554317, pi(x) = 9084
# x = 1600000
#  - Block 1 of 1: (1500000, 1600000)
#    Sieving primes in interval [1500001, 1600001)...
#     1764 primes found. Sending block [1500061, ... ,1599877] of size 13.78 kB to GPU.
#      Result: theta =  -770.1118164178098;  pi = 552
# 2024-08-11 02:52:43.325795: Point 17 of 100, x = 1600000, theta(x) = -9195.654850972127, pi(x) = 9636
# x = 1700000
#  - Block 1 of 1: (1600000, 1700000)
#    Sieving primes in interval [1600001, 1700001)...
#     1754 primes found. Sending block [1600037, ... ,1699933] of size 13.7 kB to GPU.
#      Result: theta =  -250.9019137441193;  pi = 573
# 2024-08-11 02:52:43.342868: Point 18 of 100, x = 1700000, theta(x) = -9446.556764716246, pi(x) = 10209
# x = 1800000
#  - Block 1 of 1: (1700000, 1800000)
#    Sieving primes in interval [1700001, 1800001)...
#     1738 primes found. Sending block [1700021, ... ,1799797] of size 13.58 kB to GPU.
#      Result: theta =  -1300.796137244039;  pi = 519
# 2024-08-11 02:52:43.356035: Point 19 of 100, x = 1800000, theta(x) = -10747.352901960285, pi(x) = 10728
# x = 1900000
#  - Block 1 of 1: (1800000, 1900000)
#    Sieving primes in interval [1800001, 1900001)...
#     1757 primes found. Sending block [1800037, ... ,1899949] of size 13.73 kB to GPU.
#      Result: theta =  202.5178791547931;  pi = 595
# 2024-08-11 02:52:43.370127: Point 20 of 100, x = 1900000, theta(x) = -10544.835022805491, pi(x) = 11323
# x = 2000000
#  - Block 1 of 1: (1900000, 2000000)
#    Sieving primes in interval [1900001, 2000001)...
#     1724 primes found. Sending block [1900037, ... ,1999957] of size 13.47 kB to GPU.
#      Result: theta =  -644.8119994509466;  pi = 545
# 2024-08-11 02:52:43.385144: Point 21 of 100, x = 2000000, theta(x) = -11189.647022256439, pi(x) = 11868
# x = 2100000
#  - Block 1 of 1: (2000000, 2100000)
#    Sieving primes in interval [2000001, 2100001)...
#     1718 primes found. Sending block [2000029, ... ,2099941] of size 13.42 kB to GPU.
#      Result: theta =  -951.4212014995503;  pi = 529
# 2024-08-11 02:52:43.399660: Point 22 of 100, x = 2100000, theta(x) = -12141.068223755989, pi(x) = 12397
# x = 2200000
#  - Block 1 of 1: (2100000, 2200000)
#    Sieving primes in interval [2100001, 2200001)...
#     1697 primes found. Sending block [2100053, ... ,2199941] of size 13.26 kB to GPU.
#      Result: theta =  -626.9178158294684;  pi = 537
# 2024-08-11 02:52:43.414735: Point 23 of 100, x = 2200000, theta(x) = -12767.986039585458, pi(x) = 12934
# x = 2300000
#  - Block 1 of 1: (2200000, 2300000)
#    Sieving primes in interval [2200001, 2300001)...
#     1684 primes found. Sending block [2200013, ... ,2299949] of size 13.16 kB to GPU.
#      Result: theta =  -797.1877916300713;  pi = 525
# 2024-08-11 02:52:43.432737: Point 24 of 100, x = 2300000, theta(x) = -13565.173831215528, pi(x) = 13459
# x = 2400000
#  - Block 1 of 1: (2300000, 2400000)
#    Sieving primes in interval [2300001, 2400001)...
#     1678 primes found. Sending block [2300021, ... ,2399933] of size 13.11 kB to GPU.
#      Result: theta =  -688.7440546166991;  pi = 528
# 2024-08-11 02:52:43.444736: Point 25 of 100, x = 2400000, theta(x) = -14253.917885832228, pi(x) = 13987
# x = 2500000
#  - Block 1 of 1: (2400000, 2500000)
#    Sieving primes in interval [2400001, 2500001)...
#     1724 primes found. Sending block [2400037, ... ,2499997] of size 13.47 kB to GPU.
#      Result: theta =  -720.8802518929378;  pi = 542
# 2024-08-11 02:52:43.450102: Point 26 of 100, x = 2500000, theta(x) = -14974.798137725167, pi(x) = 14529
# x = 2600000
#  - Block 1 of 1: (2500000, 2600000)
#    Sieving primes in interval [2500001, 2600001)...
#     1720 primes found. Sending block [2500109, ... ,2599981] of size 13.44 kB to GPU.
#      Result: theta =  -251.0356790187322;  pi = 562
# 2024-08-11 02:52:43.455102: Point 27 of 100, x = 2600000, theta(x) = -15225.8338167439, pi(x) = 15091
# x = 2700000
#  - Block 1 of 1: (2600000, 2700000)
#    Sieving primes in interval [2600001, 2700001)...
#     1676 primes found. Sending block [2600309, ... ,2699989] of size 13.09 kB to GPU.
#      Result: theta =  -835.6748692007479;  pi = 521
# 2024-08-11 02:52:43.461102: Point 28 of 100, x = 2700000, theta(x) = -16061.508685944647, pi(x) = 15612
# x = 2800000
#  - Block 1 of 1: (2700000, 2800000)
#    Sieving primes in interval [2700001, 2800001)...
#     1673 primes found. Sending block [2700037, ... ,2799989] of size 13.07 kB to GPU.
#      Result: theta =  -326.11300969783326;  pi = 543
# 2024-08-11 02:52:43.466610: Point 29 of 100, x = 2800000, theta(x) = -16387.62169564248, pi(x) = 16155
# x = 2900000
#  - Block 1 of 1: (2800000, 2900000)
#    Sieving primes in interval [2800001, 2900001)...
#     1699 primes found. Sending block [2800069, ... ,2899997] of size 13.27 kB to GPU.
#      Result: theta =  -409.09700366833044;  pi = 548
# 2024-08-11 02:52:43.472118: Point 30 of 100, x = 2900000, theta(x) = -16796.71869931081, pi(x) = 16703
# x = 3000000
#  - Block 1 of 1: (2900000, 3000000)
#    Sieving primes in interval [2900001, 3000001)...
#     1643 primes found. Sending block [2900069, ... ,2999957] of size 12.84 kB to GPU.
#      Result: theta =  -506.6905193140167;  pi = 525
# 2024-08-11 02:52:43.478118: Point 31 of 100, x = 3000000, theta(x) = -17303.409218624827, pi(x) = 17228
# x = 3100000
#  - Block 1 of 1: (3000000, 3100000)
#    Sieving primes in interval [3000001, 3100001)...
#     1684 primes found. Sending block [3000029, ... ,3099997] of size 13.16 kB to GPU.
#      Result: theta =  -746.9307585073992;  pi = 528
# 2024-08-11 02:52:43.484118: Point 32 of 100, x = 3100000, theta(x) = -18050.339977132226, pi(x) = 17756
# x = 3200000
#  - Block 1 of 1: (3100000, 3200000)
#    Sieving primes in interval [3100001, 3200001)...
#     1672 primes found. Sending block [3100061, ... ,3199997] of size 13.06 kB to GPU.
#      Result: theta =  14.933702946477965;  pi = 558
# 2024-08-11 02:52:43.489118: Point 33 of 100, x = 3200000, theta(x) = -18035.40627418575, pi(x) = 18314
# x = 3300000
#  - Block 1 of 1: (3200000, 3300000)
#    Sieving primes in interval [3200001, 3300001)...
#     1653 primes found. Sending block [3200069, ... ,3299957] of size 12.91 kB to GPU.
#      Result: theta =  90.05639309491968;  pi = 555
# 2024-08-11 02:52:43.494627: Point 34 of 100, x = 3300000, theta(x) = -17945.349881090828, pi(x) = 18869
# x = 3400000
#  - Block 1 of 1: (3300000, 3400000)
#    Sieving primes in interval [3300001, 3400001)...
#     1652 primes found. Sending block [3300029, ... ,3399997] of size 12.91 kB to GPU.
#      Result: theta =  -555.8804431029198;  pi = 526
# 2024-08-11 02:52:43.500284: Point 35 of 100, x = 3400000, theta(x) = -18501.230324193748, pi(x) = 19395
# x = 3500000
#  - Block 1 of 1: (3400000, 3500000)
#    Sieving primes in interval [3400001, 3500001)...
#     1655 primes found. Sending block [3400093, ... ,3499973] of size 12.93 kB to GPU.
#      Result: theta =  -805.3875870974524;  pi = 516
# 2024-08-11 02:52:43.505951: Point 36 of 100, x = 3500000, theta(x) = -19306.6179112912, pi(x) = 19911
# x = 3600000
#  - Block 1 of 1: (3500000, 3600000)
#    Sieving primes in interval [3500001, 3600001)...
#     1644 primes found. Sending block [3500149, ... ,3599941] of size 12.84 kB to GPU.
#      Result: theta =  -927.3657543721278;  pi = 507
# 2024-08-11 02:52:43.511810: Point 37 of 100, x = 3600000, theta(x) = -20233.983665663327, pi(x) = 20418
# x = 3700000
#  - Block 1 of 1: (3600000, 3700000)
#    Sieving primes in interval [3600001, 3700001)...
#     1655 primes found. Sending block [3600013, ... ,3699901] of size 12.93 kB to GPU.
#      Result: theta =  -151.0624126144125;  pi = 545
# 2024-08-11 02:52:43.518578: Point 38 of 100, x = 3700000, theta(x) = -20385.04607827774, pi(x) = 20963
# x = 3800000
#  - Block 1 of 1: (3700000, 3800000)
#    Sieving primes in interval [3700001, 3800001)...
#     1663 primes found. Sending block [3700013, ... ,3799973] of size 12.99 kB to GPU.
#      Result: theta =  -893.0919462750825;  pi = 515
# 2024-08-11 02:52:43.525085: Point 39 of 100, x = 3800000, theta(x) = -21278.138024552823, pi(x) = 21478
# x = 3900000
#  - Block 1 of 1: (3800000, 3900000)
#    Sieving primes in interval [3800001, 3900001)...
#     1669 primes found. Sending block [3800021, ... ,3899989] of size 13.04 kB to GPU.
#      Result: theta =  287.8982153508264;  pi = 569
# 2024-08-11 02:52:43.531427: Point 40 of 100, x = 3900000, theta(x) = -20990.239809201998, pi(x) = 22047
# x = 4000000
#  - Block 1 of 1: (3900000, 4000000)
#    Sieving primes in interval [3900001, 4000001)...
#     1648 primes found. Sending block [3900269, ... ,3999949] of size 12.88 kB to GPU.
#      Result: theta =  -782.3994797237505;  pi = 515
# 2024-08-11 02:52:43.540765: Point 41 of 100, x = 4000000, theta(x) = -21772.639288925748, pi(x) = 22562
# x = 4100000
#  - Block 1 of 1: (4000000, 4100000)
#    Sieving primes in interval [4000001, 4100001)...
#     1682 primes found. Sending block [4000037, ... ,4099981] of size 13.14 kB to GPU.
#      Result: theta =  -471.3757936747322;  pi = 540
# 2024-08-11 02:52:43.548974: Point 42 of 100, x = 4100000, theta(x) = -22244.01508260048, pi(x) = 23102
# x = 4200000
#  - Block 1 of 1: (4100000, 4200000)
#    Sieving primes in interval [4100001, 4200001)...
#     1647 primes found. Sending block [4100069, ... ,4199989] of size 12.87 kB to GPU.
#      Result: theta =  -982.93823568092;  pi = 506
# 2024-08-11 02:52:43.555981: Point 43 of 100, x = 4200000, theta(x) = -23226.953318281398, pi(x) = 23608
# x = 4300000
#  - Block 1 of 1: (4200000, 4300000)
#    Sieving primes in interval [4200001, 4300001)...
#     1628 primes found. Sending block [4200013, ... ,4299901] of size 12.72 kB to GPU.
#      Result: theta =  -701.9401484950217;  pi = 512
# 2024-08-11 02:52:43.562994: Point 44 of 100, x = 4300000, theta(x) = -23928.89346677642, pi(x) = 24120
# x = 4400000
#  - Block 1 of 1: (4300000, 4400000)
#    Sieving primes in interval [4300001, 4400001)...
#     1613 primes found. Sending block [4300013, ... ,4399973] of size 12.6 kB to GPU.
#      Result: theta =  -725.924666692114;  pi = 506
# 2024-08-11 02:52:43.570558: Point 45 of 100, x = 4400000, theta(x) = -24654.818133468532, pi(x) = 24626
# x = 4500000
#  - Block 1 of 1: (4400000, 4500000)
#    Sieving primes in interval [4400001, 4500001)...
#     1646 primes found. Sending block [4400021, ... ,4499933] of size 12.86 kB to GPU.
#      Result: theta =  -107.23896703054201;  pi = 544
# 2024-08-11 02:52:43.577558: Point 46 of 100, x = 4500000, theta(x) = -24762.057100499074, pi(x) = 25170
# x = 4600000
#  - Block 1 of 1: (4500000, 4600000)
#    Sieving primes in interval [4500001, 4600001)...
#     1656 primes found. Sending block [4500029, ... ,4599989] of size 12.94 kB to GPU.
#      Result: theta =  -275.8372942230192;  pi = 540
# 2024-08-11 02:52:43.583553: Point 47 of 100, x = 4600000, theta(x) = -25037.894394722094, pi(x) = 25710
# x = 4700000
#  - Block 1 of 1: (4600000, 4700000)
#    Sieving primes in interval [4600001, 4700001)...
#     1620 primes found. Sending block [4600021, ... ,4699997] of size 12.66 kB to GPU.
#      Result: theta =  -460.2596818238976;  pi = 520
# 2024-08-11 02:52:43.589553: Point 48 of 100, x = 4700000, theta(x) = -25498.15407654599, pi(x) = 26230
# x = 4800000
#  - Block 1 of 1: (4700000, 4800000)
#    Sieving primes in interval [4700001, 4800001)...
#     1617 primes found. Sending block [4700021, ... ,4799981] of size 12.63 kB to GPU.
#      Result: theta =  368.92352226443023;  pi = 555
# 2024-08-11 02:52:43.596061: Point 49 of 100, x = 4800000, theta(x) = -25129.23055428156, pi(x) = 26785
# x = 4900000
#  - Block 1 of 1: (4800000, 4900000)
#    Sieving primes in interval [4800001, 4900001)...
#     1628 primes found. Sending block [4800053, ... ,4899997] of size 12.72 kB to GPU.
#      Result: theta =  -1423.9042703822838;  pi = 481
# 2024-08-11 02:52:43.602732: Point 50 of 100, x = 4900000, theta(x) = -26553.134824663844, pi(x) = 27266
# x = 5000000
#  - Block 1 of 1: (4900000, 5000000)
#    Sieving primes in interval [4900001, 5000001)...
#     1622 primes found. Sending block [4900037, ... ,4999957] of size 12.67 kB to GPU.
#      Result: theta =  -1055.964422294182;  pi = 495
# 2024-08-11 02:52:43.609240: Point 51 of 100, x = 5000000, theta(x) = -27609.099246958027, pi(x) = 27761
# x = 5100000
#  - Block 1 of 1: (5000000, 5100000)
#    Sieving primes in interval [5000001, 5100001)...
#     1623 primes found. Sending block [5000077, ... ,5099989] of size 12.68 kB to GPU.
#      Result: theta =  -69.47571567804185;  pi = 538
# 2024-08-11 02:52:43.616749: Point 52 of 100, x = 5100000, theta(x) = -27678.57496263607, pi(x) = 28299
# x = 5200000
#  - Block 1 of 1: (5100000, 5200000)
#    Sieving primes in interval [5100001, 5200001)...
#     1638 primes found. Sending block [5100077, ... ,5199973] of size 12.8 kB to GPU.
#      Result: theta =  -881.0299804542641;  pi = 508
# 2024-08-11 02:52:43.623961: Point 53 of 100, x = 5200000, theta(x) = -28559.604943090333, pi(x) = 28807
# x = 5300000
#  - Block 1 of 1: (5200000, 5300000)
#    Sieving primes in interval [5200001, 5300001)...
#     1584 primes found. Sending block [5200021, ... ,5299997] of size 12.38 kB to GPU.
#      Result: theta =  -649.8102217074018;  pi = 500
# 2024-08-11 02:52:43.630975: Point 54 of 100, x = 5300000, theta(x) = -29209.415164797734, pi(x) = 29307
# x = 5400000
#  - Block 1 of 1: (5300000, 5400000)
#    Sieving primes in interval [5300001, 5400001)...
#     1579 primes found. Sending block [5300093, ... ,5399941] of size 12.34 kB to GPU.
#      Result: theta =  -100.8767370868494;  pi = 522
# 2024-08-11 02:52:43.637672: Point 55 of 100, x = 5400000, theta(x) = -29310.291901884582, pi(x) = 29829
# x = 5500000
#  - Block 1 of 1: (5400000, 5500000)
#    Sieving primes in interval [5400001, 5500001)...
#     1624 primes found. Sending block [5400037, ... ,5499973] of size 12.69 kB to GPU.
#      Result: theta =  -635.9836712405075;  pi = 514
# 2024-08-11 02:52:43.644182: Point 56 of 100, x = 5500000, theta(x) = -29946.27557312509, pi(x) = 30343
# x = 5600000
#  - Block 1 of 1: (5500000, 5600000)
#    Sieving primes in interval [5500001, 5600001)...
#     1590 primes found. Sending block [5500021, ... ,5599981] of size 12.42 kB to GPU.
#      Result: theta =  -954.95757592086;  pi = 489
# 2024-08-11 02:52:43.650181: Point 57 of 100, x = 5600000, theta(x) = -30901.23314904595, pi(x) = 30832
# x = 5700000
#  - Block 1 of 1: (5600000, 5700000)
#    Sieving primes in interval [5600001, 5700001)...
#     1630 primes found. Sending block [5600029, ... ,5699989] of size 12.73 kB to GPU.
#      Result: theta =  -380.87565830730375;  pi = 527
# 2024-08-11 02:52:43.656690: Point 58 of 100, x = 5700000, theta(x) = -31282.108807353256, pi(x) = 31359
# x = 5800000
#  - Block 1 of 1: (5700000, 5800000)
#    Sieving primes in interval [5700001, 5800001)...
#     1578 primes found. Sending block [5700053, ... ,5799869] of size 12.33 kB to GPU.
#      Result: theta =  -653.7209219367265;  pi = 498
# 2024-08-11 02:52:43.662197: Point 59 of 100, x = 5800000, theta(x) = -31935.82972928998, pi(x) = 31857
# x = 5900000
#  - Block 1 of 1: (5800000, 5900000)
#    Sieving primes in interval [5800001, 5900001)...
#     1602 primes found. Sending block [5800021, ... ,5899997] of size 12.52 kB to GPU.
#      Result: theta =  -350.5978781425122;  pi = 519
# 2024-08-11 02:52:43.668820: Point 60 of 100, x = 5900000, theta(x) = -32286.42760743249, pi(x) = 32376
# x = 6000000
#  - Block 1 of 1: (5900000, 6000000)
#    Sieving primes in interval [5900001, 6000001)...
#     1628 primes found. Sending block [5900093, ... ,5999933] of size 12.72 kB to GPU.
#      Result: theta =  -624.1675176228387;  pi = 516
# 2024-08-11 02:52:43.674329: Point 61 of 100, x = 6000000, theta(x) = -32910.59512505533, pi(x) = 32892
# x = 6100000
#  - Block 1 of 1: (6000000, 6100000)
#    Sieving primes in interval [6000001, 6100001)...
#     1614 primes found. Sending block [6000053, ... ,6099941] of size 12.61 kB to GPU.
#      Result: theta =  280.8818015678137;  pi = 550
# 2024-08-11 02:52:43.681177: Point 62 of 100, x = 6100000, theta(x) = -32629.71332348752, pi(x) = 33442
# x = 6200000
#  - Block 1 of 1: (6100000, 6200000)
#    Sieving primes in interval [6100001, 6200001)...
#     1598 primes found. Sending block [6100013, ... ,6199981] of size 12.48 kB to GPU.
#      Result: theta =  -203.3617188797403;  pi = 524
# 2024-08-11 02:52:43.687076: Point 63 of 100, x = 6200000, theta(x) = -32833.07504236726, pi(x) = 33966
# x = 6300000
#  - Block 1 of 1: (6200000, 6300000)
#    Sieving primes in interval [6200001, 6300001)...
#     1599 primes found. Sending block [6200141, ... ,6299957] of size 12.49 kB to GPU.
#      Result: theta =  -633.929706529853;  pi = 506
# 2024-08-11 02:52:43.693654: Point 64 of 100, x = 6300000, theta(x) = -33467.00474889711, pi(x) = 34472
# x = 6400000
#  - Block 1 of 1: (6300000, 6400000)
#    Sieving primes in interval [6300001, 6400001)...
#     1579 primes found. Sending block [6300029, ... ,6399917] of size 12.34 kB to GPU.
#      Result: theta =  62.62753933738395;  pi = 529
# 2024-08-11 02:52:43.700415: Point 65 of 100, x = 6400000, theta(x) = -33404.37720955972, pi(x) = 35001
# x = 6500000
#  - Block 1 of 1: (6400000, 6500000)
#    Sieving primes in interval [6400001, 6500001)...
#     1565 primes found. Sending block [6400013, ... ,6499949] of size 12.23 kB to GPU.
#      Result: theta =  243.0091651457748;  pi = 532
# 2024-08-11 02:52:43.706976: Point 66 of 100, x = 6500000, theta(x) = -33161.368044413946, pi(x) = 35533
# x = 6600000
#  - Block 1 of 1: (6500000, 6600000)
#    Sieving primes in interval [6500001, 6600001)...
#     1615 primes found. Sending block [6500029, ... ,6599981] of size 12.62 kB to GPU.
#      Result: theta =  -925.993008498479;  pi = 499
# 2024-08-11 02:52:43.713489: Point 67 of 100, x = 6600000, theta(x) = -34087.36105291243, pi(x) = 36032
# x = 6700000
#  - Block 1 of 1: (6600000, 6700000)
#    Sieving primes in interval [6600001, 6700001)...
#     1612 primes found. Sending block [6600053, ... ,6699949] of size 12.59 kB to GPU.
#      Result: theta =  -1728.044838124265;  pi = 464
# 2024-08-11 02:52:43.719425: Point 68 of 100, x = 6700000, theta(x) = -35815.405891036695, pi(x) = 36496
# x = 6800000
#  - Block 1 of 1: (6700000, 6800000)
#    Sieving primes in interval [6700001, 6800001)...
#     1584 primes found. Sending block [6700093, ... ,6799901] of size 12.38 kB to GPU.
#      Result: theta =  -495.2359307076883;  pi = 507
# 2024-08-11 02:52:43.725425: Point 69 of 100, x = 6800000, theta(x) = -36310.641821744386, pi(x) = 37003
# x = 6900000
#  - Block 1 of 1: (6800000, 6900000)
#    Sieving primes in interval [6800001, 6900001)...
#     1635 primes found. Sending block [6800069, ... ,6899989] of size 12.77 kB to GPU.
#      Result: theta =  259.65260962907047;  pi = 556
# 2024-08-11 02:52:43.733481: Point 70 of 100, x = 6900000, theta(x) = -36050.98921211532, pi(x) = 37559
# x = 7000000
#  - Block 1 of 1: (6900000, 7000000)
#    Sieving primes in interval [6900001, 7000001)...
#     1599 primes found. Sending block [6900053, ... ,6999997] of size 12.49 kB to GPU.
#      Result: theta =  -614.4999225303123;  pi = 507
# 2024-08-11 02:52:43.741482: Point 71 of 100, x = 7000000, theta(x) = -36665.48913464563, pi(x) = 38066
# x = 7100000
#  - Block 1 of 1: (7000000, 7100000)
#    Sieving primes in interval [7000001, 7100001)...
#     1601 primes found. Sending block [7000061, ... ,7099957] of size 12.51 kB to GPU.
#      Result: theta =  -157.7561220070372;  pi = 527
# 2024-08-11 02:52:43.748050: Point 72 of 100, x = 7100000, theta(x) = -36823.24525665266, pi(x) = 38593
# x = 7200000
#  - Block 1 of 1: (7100000, 7200000)
#    Sieving primes in interval [7100001, 7200001)...
#     1566 primes found. Sending block [7100029, ... ,7199957] of size 12.23 kB to GPU.
#      Result: theta =  -118.4295998095661;  pi = 517
# 2024-08-11 02:52:43.754558: Point 73 of 100, x = 7200000, theta(x) = -36941.67485646223, pi(x) = 39110
# x = 7300000
#  - Block 1 of 1: (7200000, 7300000)
#    Sieving primes in interval [7200001, 7300001)...
#     1574 primes found. Sending block [7200101, ... ,7299949] of size 12.3 kB to GPU.
#      Result: theta =  316.0249822914295;  pi = 538
# 2024-08-11 02:52:43.762089: Point 74 of 100, x = 7300000, theta(x) = -36625.649874170806, pi(x) = 39648
# x = 7400000
#  - Block 1 of 1: (7300000, 7400000)
#    Sieving primes in interval [7300001, 7400001)...
#     1556 primes found. Sending block [7300037, ... ,7399933] of size 12.16 kB to GPU.
#      Result: theta =  -63.195173057749685;  pi = 516
# 2024-08-11 02:52:43.768599: Point 75 of 100, x = 7400000, theta(x) = -36688.845047228555, pi(x) = 40164
# x = 7500000
#  - Block 1 of 1: (7400000, 7500000)
#    Sieving primes in interval [7400001, 7500001)...
#     1585 primes found. Sending block [7400021, ... ,7499981] of size 12.38 kB to GPU.
#      Result: theta =  -577.7229805201557;  pi = 504
# 2024-08-11 02:52:43.775263: Point 76 of 100, x = 7500000, theta(x) = -37266.56802774871, pi(x) = 40668
# x = 7600000
#  - Block 1 of 1: (7500000, 7600000)
#    Sieving primes in interval [7500001, 7600001)...
#     1601 primes found. Sending block [7500013, ... ,7599989] of size 12.51 kB to GPU.
#      Result: theta =  -277.2014379204686;  pi = 522
# 2024-08-11 02:52:43.782823: Point 77 of 100, x = 7600000, theta(x) = -37543.76946566918, pi(x) = 41190
# x = 7700000
#  - Block 1 of 1: (7600000, 7700000)
#    Sieving primes in interval [7600001, 7700001)...
#     1597 primes found. Sending block [7600013, ... ,7699981] of size 12.48 kB to GPU.
#      Result: theta =  729.1195506913955;  pi = 563
# 2024-08-11 02:52:43.789515: Point 78 of 100, x = 7700000, theta(x) = -36814.64991497779, pi(x) = 41753
# x = 7800000
#  - Block 1 of 1: (7700000, 7800000)
#    Sieving primes in interval [7700001, 7800001)...
#     1553 primes found. Sending block [7700117, ... ,7799837] of size 12.13 kB to GPU.
#      Result: theta =  198.44621729729437;  pi = 526
# 2024-08-11 02:52:43.796023: Point 79 of 100, x = 7800000, theta(x) = -36616.203697680496, pi(x) = 42279
# x = 7900000
#  - Block 1 of 1: (7800000, 7900000)
#    Sieving primes in interval [7800001, 7900001)...
#     1582 primes found. Sending block [7800029, ... ,7899989] of size 12.36 kB to GPU.
#      Result: theta =  301.56211275831447;  pi = 540
# 2024-08-11 02:52:43.802872: Point 80 of 100, x = 7900000, theta(x) = -36314.64158492218, pi(x) = 42819
# x = 8000000
#  - Block 1 of 1: (7900000, 8000000)
#    Sieving primes in interval [7900001, 8000001)...
#     1564 primes found. Sending block [7900117, ... ,7999909] of size 12.22 kB to GPU.
#      Result: theta =  -508.28200309065505;  pi = 500
# 2024-08-11 02:52:43.809872: Point 81 of 100, x = 8000000, theta(x) = -36822.92358801284, pi(x) = 43319
# x = 8100000
#  - Block 1 of 1: (8000000, 8100000)
#    Sieving primes in interval [8000001, 8100001)...
#     1562 primes found. Sending block [8000053, ... ,8099981] of size 12.2 kB to GPU.
#      Result: theta =  -588.0982316794431;  pi = 496
# 2024-08-11 02:52:43.816745: Point 82 of 100, x = 8100000, theta(x) = -37411.02181969228, pi(x) = 43815
# x = 8200000
#  - Block 1 of 1: (8100000, 8200000)
#    Sieving primes in interval [8100001, 8200001)...
#     1567 primes found. Sending block [8100133, ... ,8199941] of size 12.24 kB to GPU.
#      Result: theta =  -1129.7762340071477;  pi = 475
# 2024-08-11 02:52:43.823746: Point 83 of 100, x = 8200000, theta(x) = -38540.79805369943, pi(x) = 44290
# x = 8300000
#  - Block 1 of 1: (8200000, 8300000)
#    Sieving primes in interval [8200001, 8300001)...
#     1560 primes found. Sending block [8200013, ... ,8299981] of size 12.19 kB to GPU.
#      Result: theta =  -668.7940475161145;  pi = 492
# 2024-08-11 02:52:43.830255: Point 84 of 100, x = 8300000, theta(x) = -39209.592101215545, pi(x) = 44782
# x = 8400000
#  - Block 1 of 1: (8300000, 8400000)
#    Sieving primes in interval [8300001, 8400001)...
#     1568 primes found. Sending block [8300069, ... ,8399893] of size 12.25 kB to GPU.
#      Result: theta =  -446.2958398974045;  pi = 504
# 2024-08-11 02:52:43.837231: Point 85 of 100, x = 8400000, theta(x) = -39655.88794111295, pi(x) = 45286
# x = 8500000
#  - Block 1 of 1: (8400000, 8500000)
#    Sieving primes in interval [8400001, 8500001)...
#     1515 primes found. Sending block [8400061, ... ,8499917] of size 11.84 kB to GPU.
#      Result: theta =  -358.87894947147936;  pi = 490
# 2024-08-11 02:52:43.844810: Point 86 of 100, x = 8500000, theta(x) = -40014.76689058443, pi(x) = 45776
# x = 8600000
#  - Block 1 of 1: (8500000, 8600000)
#    Sieving primes in interval [8500001, 8600001)...
#     1581 primes found. Sending block [8500021, ... ,8599693] of size 12.35 kB to GPU.
#      Result: theta =  -622.5114113400771;  pi = 501
# 2024-08-11 02:52:43.851811: Point 87 of 100, x = 8600000, theta(x) = -40637.27830192451, pi(x) = 46277
# x = 8700000
#  - Block 1 of 1: (8600000, 8700000)
#    Sieving primes in interval [8600001, 8700001)...
#     1608 primes found. Sending block [8600029, ... ,8699981] of size 12.56 kB to GPU.
#      Result: theta =  -407.13420442771564;  pi = 519
# 2024-08-11 02:52:43.858809: Point 88 of 100, x = 8700000, theta(x) = -41044.41250635223, pi(x) = 46796
# x = 8800000
#  - Block 1 of 1: (8700000, 8800000)
#    Sieving primes in interval [8700001, 8800001)...
#     1601 primes found. Sending block [8700037, ... ,8799997] of size 12.51 kB to GPU.
#      Result: theta =  -1143.0032600356071;  pi = 486
# 2024-08-11 02:52:43.865318: Point 89 of 100, x = 8800000, theta(x) = -42187.415766387836, pi(x) = 47282
# x = 8900000
#  - Block 1 of 1: (8800000, 8900000)
#    Sieving primes in interval [8800001, 8900001)...
#     1567 primes found. Sending block [8800037, ... ,8899997] of size 12.24 kB to GPU.
#      Result: theta =  232.09776616251781;  pi = 532
# 2024-08-11 02:52:43.873319: Point 90 of 100, x = 8900000, theta(x) = -41955.31800022532, pi(x) = 47814
# x = 9000000
#  - Block 1 of 1: (8900000, 9000000)
#    Sieving primes in interval [8900001, 9000001)...
#     1562 primes found. Sending block [8900029, ... ,8999981] of size 12.2 kB to GPU.
#      Result: theta =  104.08903941201031;  pi = 525
# 2024-08-11 02:52:43.879827: Point 91 of 100, x = 9000000, theta(x) = -41851.228960813314, pi(x) = 48339
# x = 9100000
#  - Block 1 of 1: (9000000, 9100000)
#    Sieving primes in interval [9000001, 9100001)...
#     1531 primes found. Sending block [9000253, ... ,9099989] of size 11.96 kB to GPU.
#      Result: theta =  -31.975180839291824;  pi = 509
# 2024-08-11 02:52:43.887550: Point 92 of 100, x = 9100000, theta(x) = -41883.204141652604, pi(x) = 48848
# x = 9200000
#  - Block 1 of 1: (9100000, 9200000)
#    Sieving primes in interval [9100001, 9200001)...
#     1563 primes found. Sending block [9100061, ... ,9199997] of size 12.21 kB to GPU.
#      Result: theta =  649.0800124909507;  pi = 548
# 2024-08-11 02:52:43.895309: Point 93 of 100, x = 9200000, theta(x) = -41234.12412916165, pi(x) = 49396
# x = 9300000
#  - Block 1 of 1: (9200000, 9300000)
#    Sieving primes in interval [9200001, 9300001)...
#     1543 primes found. Sending block [9200021, ... ,9299957] of size 12.05 kB to GPU.
#      Result: theta =  -1788.535379285642;  pi = 440
# 2024-08-11 02:52:43.901825: Point 94 of 100, x = 9300000, theta(x) = -43022.659508447294, pi(x) = 49836
# x = 9400000
#  - Block 1 of 1: (9300000, 9400000)
#    Sieving primes in interval [9300001, 9400001)...
#     1583 primes found. Sending block [9300149, ... ,9399989] of size 12.37 kB to GPU.
#      Result: theta =  8.064770900735653;  pi = 528
# 2024-08-11 02:52:43.909822: Point 95 of 100, x = 9400000, theta(x) = -43014.594737546555, pi(x) = 50364
# x = 9500000
#  - Block 1 of 1: (9400000, 9500000)
#    Sieving primes in interval [9400001, 9500001)...
#     1525 primes found. Sending block [9400021, ... ,9499933] of size 11.91 kB to GPU.
#      Result: theta =  738.7642997980765;  pi = 539
# 2024-08-11 02:52:43.917142: Point 96 of 100, x = 9500000, theta(x) = -42275.830437748475, pi(x) = 50903
# x = 9600000
#  - Block 1 of 1: (9500000, 9600000)
#    Sieving primes in interval [9500001, 9600001)...
#     1584 primes found. Sending block [9500021, ... ,9599893] of size 12.38 kB to GPU.
#      Result: theta =  -578.6558736433371;  pi = 504
# 2024-08-11 02:52:43.924612: Point 97 of 100, x = 9600000, theta(x) = -42854.48631139181, pi(x) = 51407
# x = 9700000
#  - Block 1 of 1: (9600000, 9700000)
#    Sieving primes in interval [9600001, 9700001)...
#     1536 primes found. Sending block [9600037, ... ,9699973] of size 12.0 kB to GPU.
#      Result: theta =  120.64305297302043;  pi = 517
# 2024-08-11 02:52:43.932665: Point 98 of 100, x = 9700000, theta(x) = -42733.84325841879, pi(x) = 51924
# x = 9800000
#  - Block 1 of 1: (9700000, 9800000)
#    Sieving primes in interval [9700001, 9800001)...
#     1547 primes found. Sending block [9700213, ... ,9799997] of size 12.09 kB to GPU.
#      Result: theta =  -619.4906414926872;  pi = 490
# 2024-08-11 02:52:43.940056: Point 99 of 100, x = 9800000, theta(x) = -43353.33389991148, pi(x) = 52414
# x = 9900000
#  - Block 1 of 1: (9800000, 9900000)
#    Sieving primes in interval [9800001, 9900001)...
#     1552 primes found. Sending block [9800053, ... ,9899861] of size 12.12 kB to GPU.
#      Result: theta =  -515.4432763973916;  pi = 496
# 2024-08-11 02:52:43.948057: Point 100 of 100, x = 9900000, theta(x) = -43868.77717630887, pi(x) = 52910
